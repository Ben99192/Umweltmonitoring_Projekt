# %%
import requests
import pandas as pd
import json

response = requests.get("https://us-central1-skillful-coast-423214-a6.cloudfunctions.net/lastEntries")
df = pd.read_json(json.dumps(response.json()))


df.columns = ["index", "time", "temperature", "luftfeuchtigkeit", "pm10", "pm2.5", "senseidfk","r"]
df.drop(columns="r",inplace=True)
df
# Out:
# C:\Users\conta\AppData\Local\Temp\ipykernel_34940\3176684297.py:2: FutureWarning: Passing literal json to 'read_json' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   df = pd.read_json(json.dumps(response.json()))
#      index                           time  temperature  luftfeuchtigkeit  \
# 0  1717453  Mon, 10 Jun 2024 14:30:03 GMT        15.30             99.90
# 1  1717448  Mon, 10 Jun 2024 14:30:00 GMT        18.00             91.60
# 2  1717451  Mon, 10 Jun 2024 14:30:02 GMT        18.92             70.22
# 3  1717450  Mon, 10 Jun 2024 14:30:02 GMT        29.30             35.50
# 4  1717449  Mon, 10 Jun 2024 14:30:01 GMT        23.12             39.92
# 5  1717454  Mon, 10 Jun 2024 14:30:04 GMT        22.78              0.00
# 6  1717455  Mon, 10 Jun 2024 14:30:05 GMT        23.92             31.67
# 7  1717452  Mon, 10 Jun 2024 14:30:03 GMT        22.10             37.50
#
# ...
